# %%
class Carbon_Nanotubes:
    import csv
    import pandas as pd
    import pymongo
    def __init__(self):
        pass
    #def cond_import():
     #     global logging
      #    logging = __import__('logging', globals(), locals()) 
    def connect_database(self):
        import csv
        import pandas as pd
        import pymongo
        #import pymongo
        global url
        url=input("enter url")
        global path
        path=input("enter path")
        try:
            data = pd.read_csv(path,sep=';')
        except Exception as e:
            print("This error to be handled",e)
        else:
            print("File path is valid, please see the below initial data")
        client = pymongo.MongoClient(url)
        global db
        db=client.test
        db=client['CN_Database']
        global col
        col=db['CN_Col']
        list_to_insert=data.to_dict('records')
        col.insert_many(list_to_insert)
        print("Data set inserted in MongoDB")
    def insert_one(self):
        dict1={
        'Chiral indice n': 5,
        'Chiral indice m': 2,
        'Initial atomic coordinate u': '0,6551865', 
        'Initial atomic coordinate v': '0,3884763', 
        'Initial atomic coordinate w': '0,2511397', 
        "Calculated atomic coordinates u'": '0,671862', 
        "Calculated atomic coordinates v'": '0,383546', 
        "Calculated atomic coordinates w'": '0,250842'
        }
        try:
            col.insert_one(dict1)
        except Exception as e:
            print("This is the error to be handled")
        else:
            print("Data inserted successfully")
    def insert_many(self):
        list1=[{'Chiral indice n': 2,
                  'Chiral indice m': 1,
                  'Initial atomic coordinate u': '0,679005',
                  'Initial atomic coordinate v': '0,701318',
                  'Initial atomic coordinate w': '0,017033',
                  "Calculated atomic coordinates u'": '0,721039',
                  "Calculated atomic coordinates v'": '0,730232',
                  "Calculated atomic coordinates w'": '0,017014'},
             {'Chiral indice n': 2,
                  'Chiral indice m': 1,
                  'Initial atomic coordinate u': '0,717298',
                  'Initial atomic coordinate v': '0,642129',
                  'Initial atomic coordinate w': '0,231319',
                  "Calculated atomic coordinates u'": '0,738414',
                  "Calculated atomic coordinates v'": '0,65675',
                  "Calculated atomic coordinates w'": '0,232369'},
             {'Chiral indice n': 2,
                  'Chiral indice m': 1,
                  'Initial atomic coordinate u': '0,489336',
                  'Initial atomic coordinate v': '0,303751',
                  'Initial atomic coordinate w': '0,088462',
                  "Calculated atomic coordinates u'": '0,477676',
                  "Calculated atomic coordinates v'": '0,263221',
                  "Calculated atomic coordinates w'": '0,088712'},
             {'Chiral indice n': 2,
                  'Chiral indice m': 1,
                  'Initial atomic coordinate u': '0,413957',
                  'Initial atomic coordinate v': '0,632996',
                  'Initial atomic coordinate w': '0,040843',
                  "Calculated atomic coordinates u'": '0,408823',
                  "Calculated atomic coordinates v'": '0,657897',
                  "Calculated atomic coordinates w'": '0,039796'}]
        try:
            col.insert_many(list1)
        except Exception as e:
            print("This error to be handled",e)
        else:
            print("data inserted successfully")
    def update_many(self):
        present_data = {'Chiral indice n': 2}
        new_data = {"$set" : {'Chiral indice n': 10}}
        try:
            col.update_many(present_data,new_data)
        except Exception as e:
            print("this error to be handled",e)
        else:
            print("data updated successfully")
    def delete_many(self):
        try:
            col.delete_many({'Chiral indice n':{'$gte':11}})
        except Exception as e:
            print("this error to be handled",e)
        else:
            print("data deleted successfully")
    def find_operation(self):
        n=int(input("how many limit you want to set"))
        try:
            for i in col.find().limit(n):
                print(i)
        except Exception as e:
            print("this exception is to be handled",e)
        else:
            print("Thank you!")
    def filter_out(self):
        try:
            for i in col.find({"Calculated atomic coordinates v'": {'$gte':'0,681054'}}):
                print(i)
        except Exception as e:
            print("this exception to be handled",e)
        else:
            print("Thank you!")

# %%
a=Carbon_Nanotubes()

# %%
a.connect_database()
# Out:
# enter urlmongodb+srv://project:project@cluster0.kfg5x.mongodb.net/myFirstDatabase?retryWrites=true&w=majority
# enter pathC:\Users\USER\OneDrive\Desktop\carbon_nanotubes.csv
# File path is valid, please see the below initial data
# Data set inserted in MongoDB

# %% [markdown]
# "mongodb+srv://project:project@cluster0.kfg5x.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"

# %% [markdown]
# "C:\Users\USER\OneDrive\Desktop\carbon_nanotubes.csv"

# %%
a.insert_one()
# Out:
# Data inserted successfully

# %%
a.insert_many()
# Out:
# data inserted successfully

# %%
a.update_many()
# Out:
# data updated successfully

# %%
a.delete_many()
# Out:
# data deleted successfully

# %%
a.find_operation()
# Out:
# how many limit you want to set5
# {'_id': ObjectId('6218a02451bfff45a0393a6a'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,679005', 'Initial atomic coordinate v': '0,701318', 'Initial atomic coordinate w': '0,017033', "Calculated atomic coordinates u'": '0,721039', "Calculated atomic coordinates v'": '0,730232', "Calculated atomic coordinates w'": '0,017014'}
# {'_id': ObjectId('6218a02451bfff45a0393a6b'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,717298', 'Initial atomic coordinate v': '0,642129', 'Initial atomic coordinate w': '0,231319', "Calculated atomic coordinates u'": '0,738414', "Calculated atomic coordinates v'": '0,65675', "Calculated atomic coordinates w'": '0,232369'}
# {'_id': ObjectId('6218a02451bfff45a0393a6c'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,489336', 'Initial atomic coordinate v': '0,303751', 'Initial atomic coordinate w': '0,088462', "Calculated atomic coordinates u'": '0,477676', "Calculated atomic coordinates v'": '0,263221', "Calculated atomic coordinates w'": '0,088712'}
# {'_id': ObjectId('6218a02451bfff45a0393a6d'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,413957', 'Initial atomic coordinate v': '0,632996', 'Initial atomic coordinate w': '0,040843', "Calculated atomic coordinates u'": '0,408823', "Calculated atomic coordinates v'": '0,657897', "Calculated atomic coordinates w'": '0,039796'}
# {'_id': ObjectId('6218a02451bfff45a0393a6e'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,334292', 'Initial atomic coordinate v': '0,543401', 'Initial atomic coordinate w': '0,15989', "Calculated atomic coordinates u'": '0,303349', "Calculated atomic coordinates v'": '0,558807', "Calculated atomic coordinates w'": '0,157373'}

# %%
a.filter_out()
# Out:
# {'_id': ObjectId('6218a02451bfff45a0393a6a'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,679005', 'Initial atomic coordinate v': '0,701318', 'Initial atomic coordinate w': '0,017033', "Calculated atomic coordinates u'": '0,721039', "Calculated atomic coordinates v'": '0,730232', "Calculated atomic coordinates w'": '0,017014'}
# {'_id': ObjectId('6218a02451bfff45a0393a6f'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,510664', 'Initial atomic coordinate v': '0,696249', 'Initial atomic coordinate w': '0,255128', "Calculated atomic coordinates u'": '0,496977', "Calculated atomic coordinates v'": '0,725608', "Calculated atomic coordinates w'": '0,25597'}
# {'_id': ObjectId('6218a02451bfff45a0393a76'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,605258', 'Initial atomic coordinate v': '0,720633', 'Initial atomic coordinate w': '0,469414', "Calculated atomic coordinates u'": '0,613415', "Calculated atomic coordinates v'": '0,760009', "Calculated atomic coordinates w'": '0,469452'}
# {'_id': ObjectId('6218a02451bfff45a0393a77'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,510664', 'Initial atomic coordinate v': '0,696249', 'Initial atomic coordinate w': '0,588462', "Calculated atomic coordinates u'": '0,521991', "Calculated atomic coordinates v'": '0,736991', "Calculated atomic coordinates w'": '0,588946'}
# {'_id': ObjectId('6218a02451bfff45a0393a78'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,679005', 'Initial atomic coordinate v': '0,701318', 'Initial atomic coordinate w': '0,6837', "Calculated atomic coordinates u'": '0,718811', "Calculated atomic coordinates v'": '0,738577', "Calculated atomic coordinates w'": '0,68244'}
# {'_id': ObjectId('6218a02451bfff45a0393a79'), 'Chiral indice n': 10, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,605258', 'Initial atomic coordinate v': '0,720633', 'Initial atomic coordinate w': '0,802747', "Calculated atomic coordinates u'": '0,649178', "Calculated atomic coordinates v'": '0,766301', "Calculated atomic coordinates w'": '0,80193'}
# {'_id': ObjectId('6218a02451bfff45a0393a86'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,591598', 'Initial atomic coordinate v': '0,760361', 'Initial atomic coordinate w': '0,05909', "Calculated atomic coordinates u'": '0,59912', "Calculated atomic coordinates v'": '0,779052', "Calculated atomic coordinates w'": '0,058651'}
# {'_id': ObjectId('6218a02451bfff45a0393a8a'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,732854', 'Initial atomic coordinate v': '0,724426', 'Initial atomic coordinate w': '0,123192', "Calculated atomic coordinates u'": '0,754953', "Calculated atomic coordinates v'": '0,742501', "Calculated atomic coordinates w'": '0,123074'}
# {'_id': ObjectId('6218a02451bfff45a0393a8b'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,696244', 'Initial atomic coordinate v': '0,751243', 'Initial atomic coordinate w': '0,212936', "Calculated atomic coordinates u'": '0,716721', "Calculated atomic coordinates v'": '0,774579', "Calculated atomic coordinates w'": '0,211887'}
# {'_id': ObjectId('6218a02451bfff45a0393a8d'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,755932', 'Initial atomic coordinate v': '0,684567', 'Initial atomic coordinate w': '0,366782', "Calculated atomic coordinates u'": '0,775712', "Calculated atomic coordinates v'": '0,700545', "Calculated atomic coordinates w'": '0,366505'}
# {'_id': ObjectId('6218a02451bfff45a0393a94'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,465969', 'Initial atomic coordinate v': '0,709835', 'Initial atomic coordinate w': '0,238577', "Calculated atomic coordinates u'": '0,467543', "Calculated atomic coordinates v'": '0,732466', "Calculated atomic coordinates w'": '0,238691'}
# {'_id': ObjectId('6218a02451bfff45a0393a95'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,40427', 'Initial atomic coordinate v': '0,665341', 'Initial atomic coordinate w': '0,32832', "Calculated atomic coordinates u'": '0,398427', "Calculated atomic coordinates v'": '0,685067', "Calculated atomic coordinates w'": '0,327159'}
# {'_id': ObjectId('6218a02451bfff45a0393a96'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,591598', 'Initial atomic coordinate v': '0,760361', 'Initial atomic coordinate w': '0,392423', "Calculated atomic coordinates u'": '0,599318', "Calculated atomic coordinates v'": '0,782562', "Calculated atomic coordinates w'": '0,392936'}
# {'_id': ObjectId('6218a02451bfff45a0393a97'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,529645', 'Initial atomic coordinate v': '0,742134', 'Initial atomic coordinate w': '0,482166', "Calculated atomic coordinates u'": '0,529179', "Calculated atomic coordinates v'": '0,763965', "Calculated atomic coordinates w'": '0,48165'}
# {'_id': ObjectId('6218a02451bfff45a0393aa0'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,696244', 'Initial atomic coordinate v': '0,751243', 'Initial atomic coordinate w': '0,546269', "Calculated atomic coordinates u'": '0,706416', "Calculated atomic coordinates v'": '0,770935', "Calculated atomic coordinates w'": '0,547346'}
# {'_id': ObjectId('6218a02451bfff45a0393aa1'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,648228', 'Initial atomic coordinate v': '0,763458', 'Initial atomic coordinate w': '0,636013', "Calculated atomic coordinates u'": '0,650028', "Calculated atomic coordinates v'": '0,77941', "Calculated atomic coordinates w'": '0,636027'}
# {'_id': ObjectId('6218a02451bfff45a0393aa2'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,755932', 'Initial atomic coordinate v': '0,684567', 'Initial atomic coordinate w': '0,700115', "Calculated atomic coordinates u'": '0,767984', "Calculated atomic coordinates v'": '0,695844', "Calculated atomic coordinates w'": '0,701163'}
# {'_id': ObjectId('6218a02451bfff45a0393aa3'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,732854', 'Initial atomic coordinate v': '0,724426', 'Initial atomic coordinate w': '0,789859', "Calculated atomic coordinates u'": '0,740808', "Calculated atomic coordinates v'": '0,736904', "Calculated atomic coordinates w'": '0,789735'}
# {'_id': ObjectId('6218a02451bfff45a0393aac'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,529645', 'Initial atomic coordinate v': '0,742134', 'Initial atomic coordinate w': '0,8155', "Calculated atomic coordinates u'": '0,523304', "Calculated atomic coordinates v'": '0,760038', "Calculated atomic coordinates w'": '0,816373'}
# {'_id': ObjectId('6218a02451bfff45a0393aad'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,465969', 'Initial atomic coordinate v': '0,709835', 'Initial atomic coordinate w': '0,905243', "Calculated atomic coordinates u'": '0,456069', "Calculated atomic coordinates v'": '0,72541', "Calculated atomic coordinates w'": '0,905442'}
# {'_id': ObjectId('6218a02451bfff45a0393ab6'), 'Chiral indice n': 3, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,648228', 'Initial atomic coordinate v': '0,763458', 'Initial atomic coordinate w': '0,969346', "Calculated atomic coordinates u'": '0,654645', "Calculated atomic coordinates v'": '0,778422', "Calculated atomic coordinates w'": '0,969496'}
# {'_id': ObjectId('6218a02451bfff45a0393aba'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,637257', 'Initial atomic coordinate v': '0,791312', 'Initial atomic coordinate w': '0,032917', "Calculated atomic coordinates u'": '0,636717', "Calculated atomic coordinates v'": '0,803969', "Calculated atomic coordinates w'": '0,032929'}
# {'_id': ObjectId('6218a02451bfff45a0393abb'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,403783', 'Initial atomic coordinate v': '0,690165', 'Initial atomic coordinate w': '0,041689', "Calculated atomic coordinates u'": '0,393472', "Calculated atomic coordinates v'": '0,694676', "Calculated atomic coordinates w'": '0,041784'}
# {'_id': ObjectId('6218a02451bfff45a0393abd'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,743096', 'Initial atomic coordinate v': '0,760817', 'Initial atomic coordinate w': '0,094321', "Calculated atomic coordinates u'": '0,753137', "Calculated atomic coordinates v'": '0,775437', "Calculated atomic coordinates w'": '0,094168'}
# {'_id': ObjectId('6218a02451bfff45a0393abe'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,677708', 'Initial atomic coordinate v': '0,788935', 'Initial atomic coordinate w': '0,164496', "Calculated atomic coordinates u'": '0,682379', "Calculated atomic coordinates v'": '0,804355', "Calculated atomic coordinates w'": '0,164358'}
# {'_id': ObjectId('6218a02451bfff45a0393abf'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,766249', 'Initial atomic coordinate v': '0,735843', 'Initial atomic coordinate w': '0,2259', "Calculated atomic coordinates u'": '0,777945', "Calculated atomic coordinates v'": '0,749432', "Calculated atomic coordinates w'": '0,225798'}
# {'_id': ObjectId('6218a02451bfff45a0393ac0'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,713311', 'Initial atomic coordinate v': '0,778677', 'Initial atomic coordinate w': '0,296075', "Calculated atomic coordinates u'": '0,720745', "Calculated atomic coordinates v'": '0,794402', "Calculated atomic coordinates w'": '0,296029'}
# {'_id': ObjectId('6218a02451bfff45a0393ac5'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,450381', 'Initial atomic coordinate v': '0,723929', 'Initial atomic coordinate w': '0,173268', "Calculated atomic coordinates u'": '0,445071', "Calculated atomic coordinates v'": '0,732091', "Calculated atomic coordinates w'": '0,173231'}
# {'_id': ObjectId('6218a02451bfff45a0393ac7'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,498332', 'Initial atomic coordinate v': '0,751585', 'Initial atomic coordinate w': '0,304847', "Calculated atomic coordinates u'": '0,495486', "Calculated atomic coordinates v'": '0,763508', "Calculated atomic coordinates w'": '0,304887'}
# {'_id': ObjectId('6218a02451bfff45a0393ac8'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,403783', 'Initial atomic coordinate v': '0,690165', 'Initial atomic coordinate w': '0,375023', "Calculated atomic coordinates u'": '0,39409', "Calculated atomic coordinates v'": '0,694968', "Calculated atomic coordinates w'": '0,375015'}
# {'_id': ObjectId('6218a02451bfff45a0393ac9'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,78214', 'Initial atomic coordinate v': '0,704436', 'Initial atomic coordinate w': '0,357479', "Calculated atomic coordinates u'": '0,797217', "Calculated atomic coordinates v'": '0,718068', "Calculated atomic coordinates w'": '0,357196'}
# {'_id': ObjectId('6218a02451bfff45a0393aca'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,743096', 'Initial atomic coordinate v': '0,760817', 'Initial atomic coordinate w': '0,427654', "Calculated atomic coordinates u'": '0,754694', "Calculated atomic coordinates v'": '0,777448', "Calculated atomic coordinates w'": '0,427477'}
# {'_id': ObjectId('6218a02451bfff45a0393acb'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,790335', 'Initial atomic coordinate v': '0,667452', 'Initial atomic coordinate w': '0,489058', "Calculated atomic coordinates u'": '0,807952', "Calculated atomic coordinates v'": '0,681054', "Calculated atomic coordinates w'": '0,489132'}
# {'_id': ObjectId('6218a02451bfff45a0393acc'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,766249', 'Initial atomic coordinate v': '0,735843', 'Initial atomic coordinate w': '0,559233', "Calculated atomic coordinates u'": '0,780981', "Calculated atomic coordinates v'": '0,753937', "Calculated atomic coordinates w'": '0,559347'}
# {'_id': ObjectId('6218a02451bfff45a0393ad7'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,546329', 'Initial atomic coordinate v': '0,772379', 'Initial atomic coordinate w': '0,436426', "Calculated atomic coordinates u'": '0,546758', "Calculated atomic coordinates v'": '0,784127', "Calculated atomic coordinates w'": '0,436204'}
# {'_id': ObjectId('6218a02451bfff45a0393ad8'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,450381', 'Initial atomic coordinate v': '0,723929', 'Initial atomic coordinate w': '0,506602', "Calculated atomic coordinates u'": '0,444929', "Calculated atomic coordinates v'": '0,730721', "Calculated atomic coordinates w'": '0,506501'}
# {'_id': ObjectId('6218a02451bfff45a0393ad9'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,593062', 'Initial atomic coordinate v': '0,785743', 'Initial atomic coordinate w': '0,568005', "Calculated atomic coordinates u'": '0,597138', "Calculated atomic coordinates v'": '0,800685', "Calculated atomic coordinates w'": '0,567847'}
# {'_id': ObjectId('6218a02451bfff45a0393ada'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,498332', 'Initial atomic coordinate v': '0,751585', 'Initial atomic coordinate w': '0,638181', "Calculated atomic coordinates u'": '0,494599', "Calculated atomic coordinates v'": '0,763777', "Calculated atomic coordinates w'": '0,637935'}
# {'_id': ObjectId('6218a02451bfff45a0393adb'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,78214', 'Initial atomic coordinate v': '0,704436', 'Initial atomic coordinate w': '0,690812', "Calculated atomic coordinates u'": '0,794105', "Calculated atomic coordinates v'": '0,719372', "Calculated atomic coordinates w'": '0,691151'}
# {'_id': ObjectId('6218a02451bfff45a0393ae9'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,637257', 'Initial atomic coordinate v': '0,791312', 'Initial atomic coordinate w': '0,699584', "Calculated atomic coordinates u'": '0,641314', "Calculated atomic coordinates v'": '0,807089', "Calculated atomic coordinates w'": '0,699771'}
# {'_id': ObjectId('6218a02451bfff45a0393aea'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,546329', 'Initial atomic coordinate v': '0,772379', 'Initial atomic coordinate w': '0,769759', "Calculated atomic coordinates u'": '0,541827', "Calculated atomic coordinates v'": '0,784489', "Calculated atomic coordinates w'": '0,769828'}
# {'_id': ObjectId('6218a02451bfff45a0393aeb'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,677708', 'Initial atomic coordinate v': '0,788935', 'Initial atomic coordinate w': '0,831163', "Calculated atomic coordinates u'": '0,681167', "Calculated atomic coordinates v'": '0,802783', "Calculated atomic coordinates w'": '0,831324'}
# {'_id': ObjectId('6218a02451bfff45a0393aec'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,593062', 'Initial atomic coordinate v': '0,785743', 'Initial atomic coordinate w': '0,901338', "Calculated atomic coordinates u'": '0,588646', "Calculated atomic coordinates v'": '0,796196', "Calculated atomic coordinates w'": '0,901423'}
# {'_id': ObjectId('6218a02451bfff45a0393af9'), 'Chiral indice n': 3, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,713311', 'Initial atomic coordinate v': '0,778677', 'Initial atomic coordinate w': '0,962742', "Calculated atomic coordinates u'": '0,719155', "Calculated atomic coordinates v'": '0,792781', "Calculated atomic coordinates w'": '0,962711'}
# {'_id': ObjectId('6218a02451bfff45a0393b07'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,794352', 'Initial atomic coordinate v': '0,691116', 'Initial atomic coordinate w': '0,111416', "Calculated atomic coordinates u'": '0,807185', "Calculated atomic coordinates v'": '0,697932', "Calculated atomic coordinates w'": '0,111388'}
# {'_id': ObjectId('6218a02451bfff45a0393b09'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,560308', 'Initial atomic coordinate v': '0,783502', 'Initial atomic coordinate w': '0,016178', "Calculated atomic coordinates u'": '0,565293', "Calculated atomic coordinates v'": '0,801366', "Calculated atomic coordinates w'": '0,016747'}
# {'_id': ObjectId('6218a02451bfff45a0393b0a'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,516033', 'Initial atomic coordinate v': '0,766319', 'Initial atomic coordinate w': '0,087607', "Calculated atomic coordinates u'": '0,518262', "Calculated atomic coordinates v'": '0,783893', "Calculated atomic coordinates w'": '0,087303'}
# {'_id': ObjectId('6218a02451bfff45a0393b0b'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,681264', 'Initial atomic coordinate v': '0,79623', 'Initial atomic coordinate w': '0,135226', "Calculated atomic coordinates u'": '0,690505', "Calculated atomic coordinates v'": '0,811887', "Calculated atomic coordinates w'": '0,135963'}
# {'_id': ObjectId('6218a02451bfff45a0393b0c'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,643856', 'Initial atomic coordinate v': '0,798626', 'Initial atomic coordinate w': '0,206655', "Calculated atomic coordinates u'": '0,653283', "Calculated atomic coordinates v'": '0,815991', "Calculated atomic coordinates w'": '0,206572'}
# {'_id': ObjectId('6218a02451bfff45a0393b13'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,427407', 'Initial atomic coordinate v': '0,714623', 'Initial atomic coordinate w': '0,230464', "Calculated atomic coordinates u'": '0,424498', "Calculated atomic coordinates v'": '0,730007', "Calculated atomic coordinates w'": '0,230823'}
# {'_id': ObjectId('6218a02451bfff45a0393b14'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,385034', 'Initial atomic coordinate v': '0,681264', 'Initial atomic coordinate w': '0,301893', "Calculated atomic coordinates u'": '0,38078', "Calculated atomic coordinates v'": '0,69492', "Calculated atomic coordinates w'": '0,301449'}
# {'_id': ObjectId('6218a02451bfff45a0393b15'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,766319', 'Initial atomic coordinate v': '0,750286', 'Initial atomic coordinate w': '0,254274', "Calculated atomic coordinates u'": '0,779609', "Calculated atomic coordinates v'": '0,761253', "Calculated atomic coordinates w'": '0,255146'}
# {'_id': ObjectId('6218a02451bfff45a0393b16'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,743187', 'Initial atomic coordinate v': '0,771787', 'Initial atomic coordinate w': '0,325702', "Calculated atomic coordinates u'": '0,756305', "Calculated atomic coordinates v'": '0,783672', "Calculated atomic coordinates w'": '0,325794'}
# {'_id': ObjectId('6218a02451bfff45a0393b18'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,794352', 'Initial atomic coordinate v': '0,691116', 'Initial atomic coordinate w': '0,44475', "Calculated atomic coordinates u'": '0,807184', "Calculated atomic coordinates v'": '0,697932', "Calculated atomic coordinates w'": '0,444721'}
# {'_id': ObjectId('6218a02451bfff45a0393b21'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,560308', 'Initial atomic coordinate v': '0,783502', 'Initial atomic coordinate w': '0,349512', "Calculated atomic coordinates u'": '0,565293', "Calculated atomic coordinates v'": '0,801366', "Calculated atomic coordinates w'": '0,350081'}
# {'_id': ObjectId('6218a02451bfff45a0393b22'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,516033', 'Initial atomic coordinate v': '0,766319', 'Initial atomic coordinate w': '0,42094', "Calculated atomic coordinates u'": '0,518261', "Calculated atomic coordinates v'": '0,783893', "Calculated atomic coordinates w'": '0,420636'}
# {'_id': ObjectId('6218a02451bfff45a0393b23'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,681264', 'Initial atomic coordinate v': '0,79623', 'Initial atomic coordinate w': '0,468559', "Calculated atomic coordinates u'": '0,690505', "Calculated atomic coordinates v'": '0,811887', "Calculated atomic coordinates w'": '0,469296'}
# {'_id': ObjectId('6218a02451bfff45a0393b24'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,643856', 'Initial atomic coordinate v': '0,798626', 'Initial atomic coordinate w': '0,539988', "Calculated atomic coordinates u'": '0,653282', "Calculated atomic coordinates v'": '0,815991', "Calculated atomic coordinates w'": '0,539906'}
# {'_id': ObjectId('6218a02451bfff45a0393b2f'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,427407', 'Initial atomic coordinate v': '0,714623', 'Initial atomic coordinate w': '0,563797', "Calculated atomic coordinates u'": '0,424498', "Calculated atomic coordinates v'": '0,730007', "Calculated atomic coordinates w'": '0,564156'}
# {'_id': ObjectId('6218a02451bfff45a0393b30'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,385034', 'Initial atomic coordinate v': '0,681264', 'Initial atomic coordinate w': '0,635226', "Calculated atomic coordinates u'": '0,38078', "Calculated atomic coordinates v'": '0,69492', "Calculated atomic coordinates w'": '0,634783'}
# {'_id': ObjectId('6218a02451bfff45a0393b31'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,766319', 'Initial atomic coordinate v': '0,750286', 'Initial atomic coordinate w': '0,587607', "Calculated atomic coordinates u'": '0,779608', "Calculated atomic coordinates v'": '0,761253', "Calculated atomic coordinates w'": '0,588479'}
# {'_id': ObjectId('6218a02451bfff45a0393b32'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,743187', 'Initial atomic coordinate v': '0,771787', 'Initial atomic coordinate w': '0,659036', "Calculated atomic coordinates u'": '0,756305', "Calculated atomic coordinates v'": '0,783671', "Calculated atomic coordinates w'": '0,659127'}
# {'_id': ObjectId('6218a02451bfff45a0393b34'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,794352', 'Initial atomic coordinate v': '0,691116', 'Initial atomic coordinate w': '0,778083', "Calculated atomic coordinates u'": '0,807185', "Calculated atomic coordinates v'": '0,697932', "Calculated atomic coordinates w'": '0,778054'}
# {'_id': ObjectId('6218a02451bfff45a0393b3d'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,560308', 'Initial atomic coordinate v': '0,783502', 'Initial atomic coordinate w': '0,682845', "Calculated atomic coordinates u'": '0,565293', "Calculated atomic coordinates v'": '0,801366', "Calculated atomic coordinates w'": '0,683414'}
# {'_id': ObjectId('6218a02451bfff45a0393b3e'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,516033', 'Initial atomic coordinate v': '0,766319', 'Initial atomic coordinate w': '0,754274', "Calculated atomic coordinates u'": '0,518261', "Calculated atomic coordinates v'": '0,783893', "Calculated atomic coordinates w'": '0,75397'}
# {'_id': ObjectId('6218a02451bfff45a0393b3f'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,681264', 'Initial atomic coordinate v': '0,79623', 'Initial atomic coordinate w': '0,801893', "Calculated atomic coordinates u'": '0,690505', "Calculated atomic coordinates v'": '0,811887', "Calculated atomic coordinates w'": '0,80263'}
# {'_id': ObjectId('6218a02451bfff45a0393b40'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,643856', 'Initial atomic coordinate v': '0,798626', 'Initial atomic coordinate w': '0,873321', "Calculated atomic coordinates u'": '0,653282', "Calculated atomic coordinates v'": '0,81599', "Calculated atomic coordinates w'": '0,873239'}
# {'_id': ObjectId('6218a02451bfff45a0393b4b'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,427407', 'Initial atomic coordinate v': '0,714623', 'Initial atomic coordinate w': '0,897131', "Calculated atomic coordinates u'": '0,424498', "Calculated atomic coordinates v'": '0,730006', "Calculated atomic coordinates w'": '0,89749'}
# {'_id': ObjectId('6218a02451bfff45a0393b4c'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,385034', 'Initial atomic coordinate v': '0,681264', 'Initial atomic coordinate w': '0,968559', "Calculated atomic coordinates u'": '0,38078', "Calculated atomic coordinates v'": '0,694919', "Calculated atomic coordinates w'": '0,968116'}
# {'_id': ObjectId('6218a02451bfff45a0393b4d'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,766319', 'Initial atomic coordinate v': '0,750286', 'Initial atomic coordinate w': '0,92094', "Calculated atomic coordinates u'": '0,779609', "Calculated atomic coordinates v'": '0,761253', "Calculated atomic coordinates w'": '0,921812'}
# {'_id': ObjectId('6218a02451bfff45a0393b4e'), 'Chiral indice n': 4, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,743187', 'Initial atomic coordinate v': '0,771787', 'Initial atomic coordinate w': '0,992369', "Calculated atomic coordinates u'": '0,756305', "Calculated atomic coordinates v'": '0,783672', "Calculated atomic coordinates w'": '0,99246'}
# {'_id': ObjectId('6218a02451bfff45a0393b5a'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,818516', 'Initial atomic coordinate v': '0,679132', 'Initial atomic coordinate w': '0,068071', "Calculated atomic coordinates u'": '0,831432', "Calculated atomic coordinates v'": '0,686446', "Calculated atomic coordinates w'": '0,068597'}
# {'_id': ObjectId('6218a02451bfff45a0393b5b'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,805424', 'Initial atomic coordinate v': '0,733468', 'Initial atomic coordinate w': '0,187119', "Calculated atomic coordinates u'": '0,818275', "Calculated atomic coordinates v'": '0,743529', "Calculated atomic coordinates w'": '0,186857'}
# {'_id': ObjectId('6218a02451bfff45a0393b5d'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,548504', 'Initial atomic coordinate v': '0,797602', 'Initial atomic coordinate w': '0,11569', "Calculated atomic coordinates u'": '0,55049', "Calculated atomic coordinates v'": '0,808905', "Calculated atomic coordinates w'": '0,115307'}
# {'_id': ObjectId('6218a02451bfff45a0393b5e'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,68065', 'Initial atomic coordinate v': '0,818379', 'Initial atomic coordinate w': '0,210928', "Calculated atomic coordinates u'": '0,687882', "Calculated atomic coordinates v'": '0,83037', "Calculated atomic coordinates w'": '0,211197'}
# {'_id': ObjectId('6218a02451bfff45a0393b5f'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,617524', 'Initial atomic coordinate v': '0,815911', 'Initial atomic coordinate w': '0,329976', "Calculated atomic coordinates u'": '0,62163', "Calculated atomic coordinates v'": '0,827636', "Calculated atomic coordinates w'": '0,329481'}
# {'_id': ObjectId('6218a02451bfff45a0393b60'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,818516', 'Initial atomic coordinate v': '0,679132', 'Initial atomic coordinate w': '0,401404', "Calculated atomic coordinates u'": '0,830527', "Calculated atomic coordinates v'": '0,686314', "Calculated atomic coordinates w'": '0,401001'}
# {'_id': ObjectId('6218a02451bfff45a0393b65'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,406751', 'Initial atomic coordinate v': '0,717881', 'Initial atomic coordinate w': '0,353785', "Calculated atomic coordinates u'": '0,40435', "Calculated atomic coordinates v'": '0,724498', "Calculated atomic coordinates w'": '0,35428'}
# {'_id': ObjectId('6218a02451bfff45a0393b67'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,734718', 'Initial atomic coordinate v': '0,804882', 'Initial atomic coordinate w': '0,425214', "Calculated atomic coordinates u'": '0,745029', "Calculated atomic coordinates v'": '0,817994', "Calculated atomic coordinates w'": '0,425541'}
# {'_id': ObjectId('6218a02451bfff45a0393b68'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,68065', 'Initial atomic coordinate v': '0,818379', 'Initial atomic coordinate w': '0,544262', "Calculated atomic coordinates u'": '0,688191', "Calculated atomic coordinates v'": '0,831602', "Calculated atomic coordinates w'": '0,543768'}
# {'_id': ObjectId('6218a02451bfff45a0393b69'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,777017', 'Initial atomic coordinate v': '0,776098', 'Initial atomic coordinate w': '0,6395', "Calculated atomic coordinates u'": '0,788083', "Calculated atomic coordinates v'": '0,787117', "Calculated atomic coordinates w'": '0,63977'}
# {'_id': ObjectId('6218a02451bfff45a0393b6a'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,734718', 'Initial atomic coordinate v': '0,804882', 'Initial atomic coordinate w': '0,758547', "Calculated atomic coordinates u'": '0,74462', "Calculated atomic coordinates v'": '0,818039', "Calculated atomic coordinates w'": '0,758147'}
# {'_id': ObjectId('6218a02451bfff45a0393b73'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,477052', 'Initial atomic coordinate v': '0,764369', 'Initial atomic coordinate w': '0,568071', "Calculated atomic coordinates u'": '0,476946', "Calculated atomic coordinates v'": '0,774451', "Calculated atomic coordinates w'": '0,568352'}
# {'_id': ObjectId('6218a02451bfff45a0393b74'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,406751', 'Initial atomic coordinate v': '0,717881', 'Initial atomic coordinate w': '0,687119', "Calculated atomic coordinates u'": '0,403295', "Calculated atomic coordinates v'": '0,724069', "Calculated atomic coordinates w'": '0,686613'}
# {'_id': ObjectId('6218a02451bfff45a0393b75'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,548504', 'Initial atomic coordinate v': '0,797602', 'Initial atomic coordinate w': '0,782357', "Calculated atomic coordinates u'": '0,551101', "Calculated atomic coordinates v'": '0,809031', "Calculated atomic coordinates w'": '0,782525'}
# {'_id': ObjectId('6218a02451bfff45a0393b76'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,477052', 'Initial atomic coordinate v': '0,764369', 'Initial atomic coordinate w': '0,901404', "Calculated atomic coordinates u'": '0,476291', "Calculated atomic coordinates v'": '0,774033', "Calculated atomic coordinates w'": '0,900939'}
# {'_id': ObjectId('6218a02451bfff45a0393b77'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,805424', 'Initial atomic coordinate v': '0,733468', 'Initial atomic coordinate w': '0,853785', "Calculated atomic coordinates u'": '0,818306', "Calculated atomic coordinates v'": '0,74349', "Calculated atomic coordinates w'": '0,854149'}
# {'_id': ObjectId('6218a02451bfff45a0393b78'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,777017', 'Initial atomic coordinate v': '0,776098', 'Initial atomic coordinate w': '0,972833', "Calculated atomic coordinates u'": '0,787695', "Calculated atomic coordinates v'": '0,787174', "Calculated atomic coordinates w'": '0,972535'}
# {'_id': ObjectId('6218a02451bfff45a0393b84'), 'Chiral indice n': 4, 'Chiral indice m': 2, 'Initial atomic coordinate u': '0,617524', 'Initial atomic coordinate v': '0,815911', 'Initial atomic coordinate w': '0,996642', "Calculated atomic coordinates u'": '0,621869', "Calculated atomic coordinates v'": '0,827591', "Calculated atomic coordinates w'": '0,996998'}
# {'_id': ObjectId('6218a02451bfff45a0393b92'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,837462', 'Initial atomic coordinate v': '0,697133', 'Initial atomic coordinate w': '0,028817', "Calculated atomic coordinates u'": '0,846738', "Calculated atomic coordinates v'": '0,705715', "Calculated atomic coordinates w'": '0,029155'}
# {'_id': ObjectId('6218a02451bfff45a0393b93'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,818309', 'Initial atomic coordinate v': '0,760281', 'Initial atomic coordinate w': '0,078367', "Calculated atomic coordinates u'": '0,825667', "Calculated atomic coordinates v'": '0,768864', "Calculated atomic coordinates w'": '0,078923'}
# {'_id': ObjectId('6218a02451bfff45a0393b94'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,595393', 'Initial atomic coordinate v': '0,829463', 'Initial atomic coordinate w': '0,037826', "Calculated atomic coordinates u'": '0,595007', "Calculated atomic coordinates v'": '0,837903', "Calculated atomic coordinates w'": '0,038388'}
# {'_id': ObjectId('6218a02451bfff45a0393b95'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,698333', 'Initial atomic coordinate v': '0,837316', 'Initial atomic coordinate w': '0,082871', "Calculated atomic coordinates u'": '0,701387', "Calculated atomic coordinates v'": '0,845584', "Calculated atomic coordinates w'": '0,083443'}
# {'_id': ObjectId('6218a02451bfff45a0393b96'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,622642', 'Initial atomic coordinate v': '0,835066', 'Initial atomic coordinate w': '0,132421', "Calculated atomic coordinates u'": '0,620405', "Calculated atomic coordinates v'": '0,839401', "Calculated atomic coordinates w'": '0,132917'}
# {'_id': ObjectId('6218a02451bfff45a0393b98'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,827065', 'Initial atomic coordinate v': '0,740917', 'Initial atomic coordinate w': '0,172962', "Calculated atomic coordinates u'": '0,831618', "Calculated atomic coordinates v'": '0,743802', "Calculated atomic coordinates w'": '0,173307'}
# {'_id': ObjectId('6218a02451bfff45a0393b99'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,833465', 'Initial atomic coordinate v': '0,719817', 'Initial atomic coordinate w': '0,267556', "Calculated atomic coordinates u'": '0,834872', "Calculated atomic coordinates v'": '0,719244', "Calculated atomic coordinates w'": '0,267408'}
# {'_id': ObjectId('6218a02451bfff45a0393b9c'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,396844', 'Initial atomic coordinate v': '0,728129', 'Initial atomic coordinate w': '0,042331', "Calculated atomic coordinates u'": '0,392004', "Calculated atomic coordinates v'": '0,73275', "Calculated atomic coordinates w'": '0,042721'}
# {'_id': ObjectId('6218a02451bfff45a0393b9e'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,424606', 'Initial atomic coordinate v': '0,748578', 'Initial atomic coordinate w': '0,136925', "Calculated atomic coordinates u'": '0,41809', "Calculated atomic coordinates v'": '0,749982', "Calculated atomic coordinates w'": '0,137304'}
# {'_id': ObjectId('6218a02451bfff45a0393ba0'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,720939', 'Initial atomic coordinate v': '0,833194', 'Initial atomic coordinate w': '0,177466', "Calculated atomic coordinates u'": '0,722773', "Calculated atomic coordinates v'": '0,83738', "Calculated atomic coordinates w'": '0,177771'}
# {'_id': ObjectId('6218a02451bfff45a0393ba1'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,649007', 'Initial atomic coordinate v': '0,838255', 'Initial atomic coordinate w': '0,227016', "Calculated atomic coordinates u'": '0,647165', "Calculated atomic coordinates v'": '0,842441', "Calculated atomic coordinates w'": '0,227115'}
# {'_id': ObjectId('6218a02451bfff45a0393ba2'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,741954', 'Initial atomic coordinate v': '0,826673', 'Initial atomic coordinate w': '0,272061', "Calculated atomic coordinates u'": '0,743994', "Calculated atomic coordinates v'": '0,830405', "Calculated atomic coordinates w'": '0,271917'}
# {'_id': ObjectId('6218a02451bfff45a0393ba3'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,674298', 'Initial atomic coordinate v': '0,839006', 'Initial atomic coordinate w': '0,32161', "Calculated atomic coordinates u'": '0,67623', "Calculated atomic coordinates v'": '0,845414', "Calculated atomic coordinates w'": '0,321493'}
# {'_id': ObjectId('6218a02451bfff45a0393ba4'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,837462', 'Initial atomic coordinate v': '0,697133', 'Initial atomic coordinate w': '0,362151', "Calculated atomic coordinates u'": '0,843249', "Calculated atomic coordinates v'": '0,69801', "Calculated atomic coordinates w'": '0,361583'}
# {'_id': ObjectId('6218a02451bfff45a0393bad'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,452911', 'Initial atomic coordinate v': '0,767237', 'Initial atomic coordinate w': '0,23152', "Calculated atomic coordinates u'": '0,446991', "Calculated atomic coordinates v'": '0,768093', "Calculated atomic coordinates w'": '0,231697'}
# {'_id': ObjectId('6218a02451bfff45a0393bae'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,369825', 'Initial atomic coordinate v': '0,706036', 'Initial atomic coordinate w': '0,28107', "Calculated atomic coordinates u'": '0,362166', "Calculated atomic coordinates v'": '0,703963', "Calculated atomic coordinates w'": '0,281388'}
# {'_id': ObjectId('6218a02451bfff45a0393baf'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,481555', 'Initial atomic coordinate v': '0,78397', 'Initial atomic coordinate w': '0,326115', "Calculated atomic coordinates u'": '0,479099', "Calculated atomic coordinates v'": '0,786301', "Calculated atomic coordinates w'": '0,326133'}
# {'_id': ObjectId('6218a02451bfff45a0393bb0'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,396844', 'Initial atomic coordinate v': '0,728129', 'Initial atomic coordinate w': '0,375664', "Calculated atomic coordinates u'": '0,393293', "Calculated atomic coordinates v'": '0,728694', "Calculated atomic coordinates w'": '0,375872'}
# {'_id': ObjectId('6218a02451bfff45a0393bb1'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,761225', 'Initial atomic coordinate v': '0,817797', 'Initial atomic coordinate w': '0,366655', "Calculated atomic coordinates u'": '0,767902', "Calculated atomic coordinates v'": '0,823311', "Calculated atomic coordinates w'": '0,366168'}
# {'_id': ObjectId('6218a02451bfff45a0393bb2'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,698333', 'Initial atomic coordinate v': '0,837316', 'Initial atomic coordinate w': '0,416205', "Calculated atomic coordinates u'": '0,705207', "Calculated atomic coordinates v'": '0,844251', "Calculated atomic coordinates w'": '0,415963'}
# {'_id': ObjectId('6218a02451bfff45a0393bb3'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,778614', 'Initial atomic coordinate v': '0,806632', 'Initial atomic coordinate w': '0,46125', "Calculated atomic coordinates u'": '0,790957', "Calculated atomic coordinates v'": '0,813527', "Calculated atomic coordinates w'": '0,460641'}
# {'_id': ObjectId('6218a02451bfff45a0393bb4'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,720939', 'Initial atomic coordinate v': '0,833194', 'Initial atomic coordinate w': '0,510799', "Calculated atomic coordinates u'": '0,731672', "Calculated atomic coordinates v'": '0,841744', "Calculated atomic coordinates w'": '0,510235'}
# {'_id': ObjectId('6218a02451bfff45a0393bc2'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,510333', 'Initial atomic coordinate v': '0,798657', 'Initial atomic coordinate w': '0,420709', "Calculated atomic coordinates u'": '0,512335', "Calculated atomic coordinates v'": '0,802733', "Calculated atomic coordinates w'": '0,420582'}
# {'_id': ObjectId('6218a02451bfff45a0393bc3'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,424606', 'Initial atomic coordinate v': '0,748578', 'Initial atomic coordinate w': '0,470259', "Calculated atomic coordinates u'": '0,423944', "Calculated atomic coordinates v'": '0,750994', "Calculated atomic coordinates w'": '0,470136'}
# {'_id': ObjectId('6218a02451bfff45a0393bc4'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,539036', 'Initial atomic coordinate v': '0,811193', 'Initial atomic coordinate w': '0,515304', "Calculated atomic coordinates u'": '0,544353', "Calculated atomic coordinates v'": '0,817211', "Calculated atomic coordinates w'": '0,514772'}
# {'_id': ObjectId('6218a02451bfff45a0393bc5'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,452911', 'Initial atomic coordinate v': '0,767237', 'Initial atomic coordinate w': '0,564853', "Calculated atomic coordinates u'": '0,455717', "Calculated atomic coordinates v'": '0,77214', "Calculated atomic coordinates w'": '0,564456'}
# {'_id': ObjectId('6218a02451bfff45a0393bc6'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,793996', 'Initial atomic coordinate v': '0,793257', 'Initial atomic coordinate w': '0,555844', "Calculated atomic coordinates u'": '0,80846', "Calculated atomic coordinates v'": '0,802423', "Calculated atomic coordinates w'": '0,555292'}
# {'_id': ObjectId('6218a02451bfff45a0393bc7'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,741954', 'Initial atomic coordinate v': '0,826673', 'Initial atomic coordinate w': '0,605394', "Calculated atomic coordinates u'": '0,755739', "Calculated atomic coordinates v'": '0,839713', "Calculated atomic coordinates w'": '0,604841'}
# {'_id': ObjectId('6218a02451bfff45a0393bc8'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,807259', 'Initial atomic coordinate v': '0,77777', 'Initial atomic coordinate w': '0,650439', "Calculated atomic coordinates u'": '0,824361', "Calculated atomic coordinates v'": '0,792222', "Calculated atomic coordinates w'": '0,650182'}
# {'_id': ObjectId('6218a02451bfff45a0393bc9'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,761225', 'Initial atomic coordinate v': '0,817797', 'Initial atomic coordinate w': '0,699989', "Calculated atomic coordinates u'": '0,7749', "Calculated atomic coordinates v'": '0,833423', "Calculated atomic coordinates w'": '0,699734'}
# {'_id': ObjectId('6218a02451bfff45a0393bda'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,567458', 'Initial atomic coordinate v': '0,821486', 'Initial atomic coordinate w': '0,609898', "Calculated atomic coordinates u'": '0,575479', "Calculated atomic coordinates v'": '0,832166', "Calculated atomic coordinates w'": '0,609233'}
# {'_id': ObjectId('6218a02451bfff45a0393bdb'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,481555', 'Initial atomic coordinate v': '0,78397', 'Initial atomic coordinate w': '0,659448', "Calculated atomic coordinates u'": '0,487015', "Calculated atomic coordinates v'": '0,794846', "Calculated atomic coordinates w'": '0,658877'}
# {'_id': ObjectId('6218a02451bfff45a0393bdc'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,595393', 'Initial atomic coordinate v': '0,829463', 'Initial atomic coordinate w': '0,704493', "Calculated atomic coordinates u'": '0,605281', "Calculated atomic coordinates v'": '0,845916', "Calculated atomic coordinates w'": '0,703959'}
# {'_id': ObjectId('6218a02451bfff45a0393bdd'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,510333', 'Initial atomic coordinate v': '0,798657', 'Initial atomic coordinate w': '0,754043', "Calculated atomic coordinates u'": '0,517549', "Calculated atomic coordinates v'": '0,815731', "Calculated atomic coordinates w'": '0,753707'}
# {'_id': ObjectId('6218a02451bfff45a0393bde'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,818309', 'Initial atomic coordinate v': '0,760281', 'Initial atomic coordinate w': '0,745034', "Calculated atomic coordinates u'": '0,833274', "Calculated atomic coordinates v'": '0,774999', "Calculated atomic coordinates w'": '0,745184'}
# {'_id': ObjectId('6218a02451bfff45a0393bdf'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,778614', 'Initial atomic coordinate v': '0,806632', 'Initial atomic coordinate w': '0,794583', "Calculated atomic coordinates u'": '0,792177', "Calculated atomic coordinates v'": '0,824385', "Calculated atomic coordinates w'": '0,794794'}
# {'_id': ObjectId('6218a02451bfff45a0393be0'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,827065', 'Initial atomic coordinate v': '0,740917', 'Initial atomic coordinate w': '0,839628', "Calculated atomic coordinates u'": '0,838796', "Calculated atomic coordinates v'": '0,75503', "Calculated atomic coordinates w'": '0,840097'}
# {'_id': ObjectId('6218a02451bfff45a0393be1'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,793996', 'Initial atomic coordinate v': '0,793257', 'Initial atomic coordinate w': '0,889178', "Calculated atomic coordinates u'": '0,802664', "Calculated atomic coordinates v'": '0,808016', "Calculated atomic coordinates w'": '0,889703'}
# {'_id': ObjectId('6218a02451bfff45a0393bf3'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,622642', 'Initial atomic coordinate v': '0,835066', 'Initial atomic coordinate w': '0,799088', "Calculated atomic coordinates u'": '0,633693', "Calculated atomic coordinates v'": '0,856086', "Calculated atomic coordinates w'": '0,799034'}
# {'_id': ObjectId('6218a02451bfff45a0393bf4'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,539036', 'Initial atomic coordinate v': '0,811193', 'Initial atomic coordinate w': '0,848637', "Calculated atomic coordinates u'": '0,54482', "Calculated atomic coordinates v'": '0,829505', "Calculated atomic coordinates w'": '0,848663'}
# {'_id': ObjectId('6218a02451bfff45a0393bf5'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,649007', 'Initial atomic coordinate v': '0,838255', 'Initial atomic coordinate w': '0,893682', "Calculated atomic coordinates u'": '0,656525', "Calculated atomic coordinates v'": '0,856653', "Calculated atomic coordinates w'": '0,894128'}
# {'_id': ObjectId('6218a02451bfff45a0393bf6'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,567458', 'Initial atomic coordinate v': '0,821486', 'Initial atomic coordinate w': '0,943232', "Calculated atomic coordinates u'": '0,569414', "Calculated atomic coordinates v'": '0,835015', "Calculated atomic coordinates w'": '0,943698'}
# {'_id': ObjectId('6218a02451bfff45a0393bf7'), 'Chiral indice n': 4, 'Chiral indice m': 3, 'Initial atomic coordinate u': '0,833465', 'Initial atomic coordinate v': '0,719817', 'Initial atomic coordinate w': '0,934223', "Calculated atomic coordinates u'": '0,843313', "Calculated atomic coordinates v'": '0,731687', "Calculated atomic coordinates w'": '0,934661'}
# ...
# {'_id': ObjectId('6218a78051bfff45a0399ed5'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,649815', 'Initial atomic coordinate v': '0,881864', 'Initial atomic coordinate w': '0,443186', "Calculated atomic coordinates u'": '0,652583', "Calculated atomic coordinates v'": '0,888822', "Calculated atomic coordinates w'": '0,44317'}
# {'_id': ObjectId('6218a78051bfff45a0399ed6'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,760656', 'Initial atomic coordinate v': '0,87548', 'Initial atomic coordinate w': '0,466017', "Calculated atomic coordinates u'": '0,766131', "Calculated atomic coordinates v'": '0,88295', "Calculated atomic coordinates w'": '0,466125'}
# {'_id': ObjectId('6218a78051bfff45a0399ed7'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,748236', 'Initial atomic coordinate v': '0,878755', 'Initial atomic coordinate w': '0,50483', "Calculated atomic coordinates u'": '0,753423', "Calculated atomic coordinates v'": '0,886374', "Calculated atomic coordinates w'": '0,505001'}
# {'_id': ObjectId('6218a78051bfff45a0399ed8'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,883069', 'Initial atomic coordinate v': '0,723148', 'Initial atomic coordinate w': '0,472866', "Calculated atomic coordinates u'": '0,8899', "Calculated atomic coordinates v'": '0,727096', "Calculated atomic coordinates w'": '0,472987'}
# {'_id': ObjectId('6218a78051bfff45a0399ed9'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,881144', 'Initial atomic coordinate v': '0,736429', 'Initial atomic coordinate w': '0,511679', "Calculated atomic coordinates u'": '0,888176', "Calculated atomic coordinates v'": '0,740201', "Calculated atomic coordinates w'": '0,511898'}
# {'_id': ObjectId('6218a78051bfff45a0399eea'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,504841', 'Initial atomic coordinate v': '0,835644', 'Initial atomic coordinate w': '0,459168', "Calculated atomic coordinates u'": '0,505214', "Calculated atomic coordinates v'": '0,841241', "Calculated atomic coordinates w'": '0,459219'}
# {'_id': ObjectId('6218a78051bfff45a0399eeb'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,488283', 'Initial atomic coordinate v': '0,827237', 'Initial atomic coordinate w': '0,49798', "Calculated atomic coordinates u'": '0,488706', "Calculated atomic coordinates v'": '0,833603', "Calculated atomic coordinates w'": '0,498139'}
# {'_id': ObjectId('6218a78051bfff45a0399eec'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,61879', 'Initial atomic coordinate v': '0,876369', 'Initial atomic coordinate w': '0,520811', "Calculated atomic coordinates u'": '0,621955', "Calculated atomic coordinates v'": '0,884677', "Calculated atomic coordinates w'": '0,521053'}
# {'_id': ObjectId('6218a78051bfff45a0399eed'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,602934', 'Initial atomic coordinate v': '0,872573', 'Initial atomic coordinate w': '0,559624', "Calculated atomic coordinates u'": '0,606329', "Calculated atomic coordinates v'": '0,88088', "Calculated atomic coordinates w'": '0,5599'}
# {'_id': ObjectId('6218a78051bfff45a0399eee'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,83291', 'Initial atomic coordinate v': '0,833589', 'Initial atomic coordinate w': '0,527661', "Calculated atomic coordinates u'": '0,838495', "Calculated atomic coordinates v'": '0,838554', "Calculated atomic coordinates w'": '0,527894'}
# {'_id': ObjectId('6218a78051bfff45a0399eef'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,824299', 'Initial atomic coordinate v': '0,841532', 'Initial atomic coordinate w': '0,566474', "Calculated atomic coordinates u'": '0,830462', "Calculated atomic coordinates v'": '0,846956', "Calculated atomic coordinates w'": '0,566742'}
# {'_id': ObjectId('6218a78051bfff45a0399ef0'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,875181', 'Initial atomic coordinate v': '0,761653', 'Initial atomic coordinate w': '0,589305', "Calculated atomic coordinates u'": '0,88268', "Calculated atomic coordinates v'": '0,766198', "Calculated atomic coordinates w'": '0,589609'}
# {'_id': ObjectId('6218a78051bfff45a0399ef1'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,871154', 'Initial atomic coordinate v': '0,77355', 'Initial atomic coordinate w': '0,628117', "Calculated atomic coordinates u'": '0,878675', "Calculated atomic coordinates v'": '0,779131', "Calculated atomic coordinates w'": '0,628354'}
# {'_id': ObjectId('6218a78051bfff45a0399f02'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,343875', 'Initial atomic coordinate v': '0,726526', 'Initial atomic coordinate w': '0,513962', "Calculated atomic coordinates u'": '0,34156', "Calculated atomic coordinates v'": '0,732048', "Calculated atomic coordinates w'": '0,514196'}
# {'_id': ObjectId('6218a78051bfff45a0399f03'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,328888', 'Initial atomic coordinate v': '0,712934', 'Initial atomic coordinate w': '0,552775', "Calculated atomic coordinates u'": '0,32739', "Calculated atomic coordinates v'": '0,717282', "Calculated atomic coordinates w'": '0,553035'}
# {'_id': ObjectId('6218a78051bfff45a0399f04'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,455262', 'Initial atomic coordinate v': '0,808621', 'Initial atomic coordinate w': '0,575606', "Calculated atomic coordinates u'": '0,456118', "Calculated atomic coordinates v'": '0,815077', "Calculated atomic coordinates w'": '0,57586'}
# {'_id': ObjectId('6218a78051bfff45a0399f05'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,43886', 'Initial atomic coordinate v': '0,798447', 'Initial atomic coordinate w': '0,614419', "Calculated atomic coordinates u'": '0,438515', "Calculated atomic coordinates v'": '0,80378', "Calculated atomic coordinates w'": '0,614616'}
# {'_id': ObjectId('6218a78051bfff45a0399f06'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,722041', 'Initial atomic coordinate v': '0,883195', 'Initial atomic coordinate w': '0,582455', "Calculated atomic coordinates u'": '0,72733', "Calculated atomic coordinates v'": '0,890592', "Calculated atomic coordinates w'": '0,582747'}
# {'_id': ObjectId('6218a78051bfff45a0399f07'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,708314', 'Initial atomic coordinate v': '0,884353', 'Initial atomic coordinate w': '0,621268', "Calculated atomic coordinates u'": '0,712704', "Calculated atomic coordinates v'": '0,891794', "Calculated atomic coordinates w'": '0,621507'}
# {'_id': ObjectId('6218a78051bfff45a0399f08'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,805292', 'Initial atomic coordinate v': '0,855508', 'Initial atomic coordinate w': '0,644099', "Calculated atomic coordinates u'": '0,811953', "Calculated atomic coordinates v'": '0,862722', "Calculated atomic coordinates w'": '0,644226'}
# {'_id': ObjectId('6218a78051bfff45a0399f09'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,794932', 'Initial atomic coordinate v': '0,861515', 'Initial atomic coordinate w': '0,682912', "Calculated atomic coordinates u'": '0,801097', "Calculated atomic coordinates v'": '0,868791', "Calculated atomic coordinates w'": '0,68294'}
# {'_id': ObjectId('6218a78051bfff45a0399f0a'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,88458', 'Initial atomic coordinate v': '0,680929', 'Initial atomic coordinate w': '0,356428', "Calculated atomic coordinates u'": '0,891277', "Calculated atomic coordinates v'": '0,683586', "Calculated atomic coordinates w'": '0,356207'}
# {'_id': ObjectId('6218a78051bfff45a0399f19'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,299892', 'Initial atomic coordinate v': '0,684592', 'Initial atomic coordinate w': '0,630401', "Calculated atomic coordinates u'": '0,297186', "Calculated atomic coordinates v'": '0,687803', "Calculated atomic coordinates w'": '0,630554'}
# {'_id': ObjectId('6218a78051bfff45a0399f1b'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,570679', 'Initial atomic coordinate v': '0,86292', 'Initial atomic coordinate w': '0,63725', "Calculated atomic coordinates u'": '0,572333', "Calculated atomic coordinates v'": '0,86962', "Calculated atomic coordinates w'": '0,637358'}
# {'_id': ObjectId('6218a78051bfff45a0399f1c'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,55434', 'Initial atomic coordinate v': '0,857081', 'Initial atomic coordinate w': '0,676063', "Calculated atomic coordinates u'": '0,555795', "Calculated atomic coordinates v'": '0,864326', "Calculated atomic coordinates w'": '0,676087'}
# {'_id': ObjectId('6218a78051bfff45a0399f1d'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,67973', 'Initial atomic coordinate v': '0,884532', 'Initial atomic coordinate w': '0,698894', "Calculated atomic coordinates u'": '0,683624', "Calculated atomic coordinates v'": '0,892182', "Calculated atomic coordinates w'": '0,698782'}
# {'_id': ObjectId('6218a78051bfff45a0399f1e'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,664925', 'Initial atomic coordinate v': '0,883553', 'Initial atomic coordinate w': '0,737706', "Calculated atomic coordinates u'": '0,667492', "Calculated atomic coordinates v'": '0,890395', "Calculated atomic coordinates w'": '0,737501'}
# {'_id': ObjectId('6218a78051bfff45a0399f1f'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,861048', 'Initial atomic coordinate v': '0,795802', 'Initial atomic coordinate w': '0,705743', "Calculated atomic coordinates u'": '0,868212', "Calculated atomic coordinates v'": '0,80208', "Calculated atomic coordinates w'": '0,705663'}
# {'_id': ObjectId('6218a78051bfff45a0399f20'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,854987', 'Initial atomic coordinate v': '0,806117', 'Initial atomic coordinate w': '0,744556', "Calculated atomic coordinates u'": '0,861959', "Calculated atomic coordinates v'": '0,812952', "Calculated atomic coordinates w'": '0,744372'}
# {'_id': ObjectId('6218a78051bfff45a0399f21'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,884285', 'Initial atomic coordinate v': '0,709454', 'Initial atomic coordinate w': '0,767387', "Calculated atomic coordinates u'": '0,891557', "Calculated atomic coordinates v'": '0,714065', "Calculated atomic coordinates w'": '0,767111'}
# {'_id': ObjectId('6218a78051bfff45a0399f22'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,883069', 'Initial atomic coordinate v': '0,723148', 'Initial atomic coordinate w': '0,8062', "Calculated atomic coordinates u'": '0,890781', "Calculated atomic coordinates v'": '0,728763', "Calculated atomic coordinates w'": '0,805887'}
# {'_id': ObjectId('6218a78051bfff45a0399f33'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,406427', 'Initial atomic coordinate v': '0,776461', 'Initial atomic coordinate w': '0,692044', "Calculated atomic coordinates u'": '0,40553', "Calculated atomic coordinates v'": '0,781363', "Calculated atomic coordinates w'": '0,691957'}
# {'_id': ObjectId('6218a78051bfff45a0399f34'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,390456', 'Initial atomic coordinate v': '0,76469', 'Initial atomic coordinate w': '0,730857', "Calculated atomic coordinates u'": '0,388173', "Calculated atomic coordinates v'": '0,767972', "Calculated atomic coordinates w'": '0,730632'}
# {'_id': ObjectId('6218a78051bfff45a0399f35'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,52139', 'Initial atomic coordinate v': '0,84343', 'Initial atomic coordinate w': '0,753688', "Calculated atomic coordinates u'": '0,521044', "Calculated atomic coordinates v'": '0,848411', "Calculated atomic coordinates w'": '0,753414'}
# {'_id': ObjectId('6218a78051bfff45a0399f36'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,504841', 'Initial atomic coordinate v': '0,835644', 'Initial atomic coordinate w': '0,792501', "Calculated atomic coordinates u'": '0,504281', "Calculated atomic coordinates v'": '0,840646', "Calculated atomic coordinates w'": '0,79217'}
# {'_id': ObjectId('6218a78051bfff45a0399f37'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,772593', 'Initial atomic coordinate v': '0,87151', 'Initial atomic coordinate w': '0,760538', "Calculated atomic coordinates u'": '0,778034', "Calculated atomic coordinates v'": '0,87924', "Calculated atomic coordinates w'": '0,760273'}
# {'_id': ObjectId('6218a78051bfff45a0399f38'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,760656', 'Initial atomic coordinate v': '0,87548', 'Initial atomic coordinate w': '0,79935', "Calculated atomic coordinates u'": '0,765262', "Calculated atomic coordinates v'": '0,883088', "Calculated atomic coordinates w'": '0,799041'}
# {'_id': ObjectId('6218a78051bfff45a0399f39'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,840905', 'Initial atomic coordinate v': '0,825028', 'Initial atomic coordinate w': '0,822181', "Calculated atomic coordinates u'": '0,84641', "Calculated atomic coordinates v'": '0,831315', "Calculated atomic coordinates w'": '0,821916'}
# {'_id': ObjectId('6218a78051bfff45a0399f3a'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,83291', 'Initial atomic coordinate v': '0,833589', 'Initial atomic coordinate w': '0,860994', "Calculated atomic coordinates u'": '0,837947', "Calculated atomic coordinates v'": '0,839242', "Calculated atomic coordinates w'": '0,860789'}
# {'_id': ObjectId('6218a78051bfff45a0399f4b'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,35915', 'Initial atomic coordinate v': '0,739699', 'Initial atomic coordinate w': '0,808483', "Calculated atomic coordinates u'": '0,355883', "Calculated atomic coordinates v'": '0,743543', "Calculated atomic coordinates w'": '0,808137'}
# {'_id': ObjectId('6218a78051bfff45a0399f4c'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,343875', 'Initial atomic coordinate v': '0,726526', 'Initial atomic coordinate w': '0,847295', "Calculated atomic coordinates u'": '0,340531', "Calculated atomic coordinates v'": '0,730866', "Calculated atomic coordinates w'": '0,846983'}
# {'_id': ObjectId('6218a78051bfff45a0399f4d'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,634427', 'Initial atomic coordinate v': '0,879468', 'Initial atomic coordinate w': '0,815332', "Calculated atomic coordinates u'": '0,636531', "Calculated atomic coordinates v'": '0,886812', "Calculated atomic coordinates w'": '0,815013'}
# {'_id': ObjectId('6218a78051bfff45a0399f4e'), 'Chiral indice n': 8, 'Chiral indice m': 1, 'Initial atomic coordinate u': '0,61879', 'Initial atomic coordinate v': '0,876369', 'Initial atomic coordinate w': '0,854145', "Calculated atomic coordinates u'": '0,620508', "Calculated atomic coordinates v'": '0,88419', "Calculated atomic coordinates w'": '0,853862'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
